# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import Imputer
from IPython.display import display, HTML

# %%
datos = pd.read_csv('On_Time_On_Time_Performance_2015_1.csv') #cargamos archivo
# Out:
# /usr/local/bin/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (77,84,85) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dp = datos[[
    'Year',
    'Quarter',
    'Month',                   
'DayofMonth',              
'DayOfWeek',               
'FlightDate',             
'UniqueCarrier',          
'AirlineID',               
'Carrier',                
'TailNum',                
'FlightNum',               
'OriginAirportID',         
'OriginAirportSeqID',           
'Origin',                 
'OriginCityName',                            
'DestAirportID',          
'DestAirportSeqID',           
'Dest',                                              
'CRSDepTime', 
'DepTime',
'DepDelay',
'DepDelayMinutes',
'DepDel15',
'DepartureDelayGroups',
'DepTimeBlk',
'TaxiOut',
'WheelsOff',
'WheelsOn',
'TaxiIn',
'CRSArrTime',
'ArrTime',
'ArrDelay',
'ArrDelayMinutes',
'ArrDel15',
'ArrivalDelayGroups',
'ArrTimeBlk',
'Cancelled',
'CancellationCode',
'Diverted',
'ActualElapsedTime',
'AirTime',
'Flights',
'Distance',
'CarrierDelay',
'WeatherDelay',
'NASDelay',
'SecurityDelay',
'LateAircraftDelay',
'TotalAddGTime'
]]
display(dp)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate UniqueCarrier  \
# 0       2015        1      1           1          4  2015-01-01            AA
# 1       2015        1      1           2          5  2015-01-02            AA
# 2       2015        1      1           3          6  2015-01-03            AA
# 3       2015        1      1           4          7  2015-01-04            AA
# 4       2015        1      1           5          1  2015-01-05            AA
# 5       2015        1      1           6          2  2015-01-06            AA
# 6       2015        1      1           7          3  2015-01-07            AA
# 7       2015        1      1           8          4  2015-01-08            AA
# 8       2015        1      1           9          5  2015-01-09            AA
# 9       2015        1      1          10          6  2015-01-10            AA
# 10      2015        1      1          11          7  2015-01-11            AA
# 11      2015        1      1          12          1  2015-01-12            AA
# 12      2015        1      1          13          2  2015-01-13            AA
# 13      2015        1      1          14          3  2015-01-14            AA
# 14      2015        1      1          15          4  2015-01-15            AA
# 15      2015        1      1          16          5  2015-01-16            AA
# 16      2015        1      1          17          6  2015-01-17            AA
# 17      2015        1      1          18          7  2015-01-18            AA
# 18      2015        1      1          19          1  2015-01-19            AA
# 19      2015        1      1          20          2  2015-01-20            AA
# 20      2015        1      1          21          3  2015-01-21            AA
# 21      2015        1      1          22          4  2015-01-22            AA
# 22      2015        1      1          23          5  2015-01-23            AA
# 23      2015        1      1          24          6  2015-01-24            AA
# 24      2015        1      1          25          7  2015-01-25            AA
# 25      2015        1      1          26          1  2015-01-26            AA
# 26      2015        1      1          27          2  2015-01-27            AA
# 27      2015        1      1          28          3  2015-01-28            AA
# 28      2015        1      1          29          4  2015-01-29            AA
# 29      2015        1      1          30          5  2015-01-30            AA
# ...      ...      ...    ...         ...        ...         ...           ...
# 469938  2015        1      1           3          6  2015-01-03            NK
# 469939  2015        1      1           4          7  2015-01-04            NK
# 469940  2015        1      1           5          1  2015-01-05            NK
# 469941  2015        1      1           6          2  2015-01-06            NK
# 469942  2015        1      1           7          3  2015-01-07            NK
# 469943  2015        1      1           8          4  2015-01-08            NK
# 469944  2015        1      1           9          5  2015-01-09            NK
# 469945  2015        1      1          10          6  2015-01-10            NK
# 469946  2015        1      1          11          7  2015-01-11            NK
# 469947  2015        1      1          12          1  2015-01-12            NK
# 469948  2015        1      1          13          2  2015-01-13            NK
# 469949  2015        1      1          14          3  2015-01-14            NK
# 469950  2015        1      1          15          4  2015-01-15            NK
# 469951  2015        1      1          16          5  2015-01-16            NK
# 469952  2015        1      1          17          6  2015-01-17            NK
# 469953  2015        1      1          18          7  2015-01-18            NK
# 469954  2015        1      1          19          1  2015-01-19            NK
# 469955  2015        1      1          20          2  2015-01-20            NK
# 469956  2015        1      1          21          3  2015-01-21            NK
# 469957  2015        1      1          22          4  2015-01-22            NK
# 469958  2015        1      1          23          5  2015-01-23            NK
# 469959  2015        1      1          24          6  2015-01-24            NK
# 469960  2015        1      1          25          7  2015-01-25            NK
# 469961  2015        1      1          26          1  2015-01-26            NK
# 469962  2015        1      1          27          2  2015-01-27            NK
# 469963  2015        1      1          28          3  2015-01-28            NK
# 469964  2015        1      1          29          4  2015-01-29            NK
# 469965  2015        1      1          30          5  2015-01-30            NK
# 469966  2015        1      1          31          6  2015-01-31            NK
# 469967  2015        1      1           1          4  2015-01-01            NK
#
#         AirlineID Carrier TailNum      ...        ActualElapsedTime  AirTime  \
# 0           19805      AA  N787AA      ...                    402.0    378.0
# 1           19805      AA  N795AA      ...                    381.0    357.0
# 2           19805      AA  N788AA      ...                    358.0    330.0
# 3           19805      AA  N791AA      ...                    385.0    352.0
# 4           19805      AA  N783AA      ...                    389.0    338.0
# 5           19805      AA  N799AA      ...                    424.0    335.0
# 6           19805      AA  N784AA      ...                    382.0    341.0
# 7           19805      AA  N787AA      ...                    362.0    333.0
# 8           19805      AA  N795AA      ...                    400.0    353.0
# 9           19805      AA  N790AA      ...                    392.0    345.0
# 10          19805      AA  N786AA      ...                    365.0    337.0
# 11          19805      AA  N790AA      ...                    397.0    354.0
# 12          19805      AA  N796AA      ...                    361.0    336.0
# 13          19805      AA  N793AA      ...                    330.0    302.0
# 14          19805      AA  N790AA      ...                    399.0    320.0
# 15          19805      AA  N797AA      ...                    366.0    321.0
# 16          19805      AA  N795AA      ...                    365.0    343.0
# 17          19805      AA  N786AA      ...                    380.0    340.0
# 18          19805      AA  N785AA      ...                    384.0    359.0
# 19          19805      AA  N797AA      ...                    370.0    349.0
# 20          19805      AA  N789AA      ...                    349.0    327.0
# 21          19805      AA  N790AA      ...                    358.0    324.0
# 22          19805      AA  N790AA      ...                    352.0    328.0
# 23          19805      AA  N787AA      ...                    371.0    323.0
# 24          19805      AA  N791AA      ...                    342.0    308.0
# 25          19805      AA  N783AA      ...                    406.0    337.0
# 26          19805      AA     NaN      ...                      NaN      NaN
# 27          19805      AA     NaN      ...                      NaN      NaN
# 28          19805      AA  N794AA      ...                    382.0    349.0
# 29          19805      AA  N792AA      ...                    404.0    352.0
# ...           ...     ...     ...      ...                      ...      ...
# 469938      20416      NK  N505NK      ...                     79.0     61.0
# 469939      20416      NK  N503NK      ...                     86.0     65.0
# 469940      20416      NK  N508NK      ...                     84.0     64.0
# 469941      20416      NK  N503NK      ...                     90.0     68.0
# 469942      20416      NK  N508NK      ...                     92.0     71.0
# 469943      20416      NK  N503NK      ...                     83.0     67.0
# 469944      20416      NK  N508NK      ...                     88.0     69.0
# 469945      20416      NK  N503NK      ...                     77.0     62.0
# 469946      20416      NK  N508NK      ...                     87.0     66.0
# 469947      20416      NK  N503NK      ...                     82.0     64.0
# 469948      20416      NK  N514NK      ...                    103.0     66.0
# 469949      20416      NK  N528NK      ...                     82.0     66.0
# 469950      20416      NK  N508NK      ...                     78.0     61.0
# 469951      20416      NK  N528NK      ...                     79.0     63.0
# 469952      20416      NK  N508NK      ...                     79.0     62.0
# 469953      20416      NK  N528NK      ...                     77.0     61.0
# 469954      20416      NK  N505NK      ...                     88.0     63.0
# 469955      20416      NK  N521NK      ...                     79.0     63.0
# 469956      20416      NK  N505NK      ...                     83.0     66.0
# 469957      20416      NK  N522NK      ...                     82.0     63.0
# 469958      20416      NK  N502NK      ...                     85.0     66.0
# 469959      20416      NK  N524NK      ...                     83.0     67.0
# 469960      20416      NK  N502NK      ...                     87.0     68.0
# 469961      20416      NK  N524NK      ...                     83.0     71.0
# 469962      20416      NK  N502NK      ...                     82.0     65.0
# 469963      20416      NK  N524NK      ...                     82.0     64.0
# 469964      20416      NK  N502NK      ...                     82.0     64.0
# 469965      20416      NK  N519NK      ...                     89.0     66.0
# 469966      20416      NK  N502NK      ...                     95.0     69.0
# 469967      20416      NK  N502NK      ...                    186.0    167.0
#
#         Flights Distance CarrierDelay  WeatherDelay  NASDelay SecurityDelay  \
# 0           1.0   2475.0          NaN           NaN       NaN           NaN
# 1           1.0   2475.0          NaN           NaN       NaN           NaN
# 2           1.0   2475.0          NaN           NaN       NaN           NaN
# 3           1.0   2475.0          NaN           NaN       NaN           NaN
# 4           1.0   2475.0          NaN           NaN       NaN           NaN
# 5           1.0   2475.0          0.0           0.0      25.0           0.0
# 6           1.0   2475.0          NaN           NaN       NaN           NaN
# 7           1.0   2475.0          NaN           NaN       NaN           NaN
# 8           1.0   2475.0          NaN           NaN       NaN           NaN
# 9           1.0   2475.0          NaN           NaN       NaN           NaN
# 10          1.0   2475.0          NaN           NaN       NaN           NaN
# 11          1.0   2475.0          NaN           NaN       NaN           NaN
# 12          1.0   2475.0          NaN           NaN       NaN           NaN
# 13          1.0   2475.0          NaN           NaN       NaN           NaN
# 14          1.0   2475.0          NaN           NaN       NaN           NaN
# 15          1.0   2475.0          NaN           NaN       NaN           NaN
# 16          1.0   2475.0          NaN           NaN       NaN           NaN
# 17          1.0   2475.0          NaN           NaN       NaN           NaN
# 18          1.0   2475.0          NaN           NaN       NaN           NaN
# 19          1.0   2475.0          NaN           NaN       NaN           NaN
# 20          1.0   2475.0          NaN           NaN       NaN           NaN
# 21          1.0   2475.0          NaN           NaN       NaN           NaN
# 22          1.0   2475.0          NaN           NaN       NaN           NaN
# 23          1.0   2475.0          0.0          79.0       0.0           0.0
# 24          1.0   2475.0          NaN           NaN       NaN           NaN
# 25          1.0   2475.0          NaN           NaN       NaN           NaN
# 26          1.0   2475.0          NaN           NaN       NaN           NaN
# 27          1.0   2475.0          NaN           NaN       NaN           NaN
# 28          1.0   2475.0          NaN           NaN       NaN           NaN
# 29          1.0   2475.0          NaN           NaN       NaN           NaN
# ...         ...      ...          ...           ...       ...           ...
# 469938      1.0    407.0          NaN           NaN       NaN           NaN
# 469939      1.0    407.0          NaN           NaN       NaN           NaN
# 469940      1.0    407.0          NaN           NaN       NaN           NaN
# 469941      1.0    407.0          NaN           NaN       NaN           NaN
# 469942      1.0    407.0          NaN           NaN       NaN           NaN
# 469943      1.0    407.0          NaN           NaN       NaN           NaN
# 469944      1.0    407.0          NaN           NaN       NaN           NaN
# 469945      1.0    407.0          NaN           NaN       NaN           NaN
# 469946      1.0    407.0          NaN           NaN       NaN           NaN
# 469947      1.0    407.0          NaN           NaN       NaN           NaN
# 469948      1.0    407.0          3.0           0.0      20.0           0.0
# 469949      1.0    407.0          NaN           NaN       NaN           NaN
# 469950      1.0    407.0          NaN           NaN       NaN           NaN
# 469951      1.0    407.0          NaN           NaN       NaN           NaN
# 469952      1.0    407.0          NaN           NaN       NaN           NaN
# 469953      1.0    407.0          NaN           NaN       NaN           NaN
# 469954      1.0    407.0          NaN           NaN       NaN           NaN
# 469955      1.0    407.0          NaN           NaN       NaN           NaN
# 469956      1.0    407.0          NaN           NaN       NaN           NaN
# 469957      1.0    407.0          NaN           NaN       NaN           NaN
# 469958      1.0    407.0          NaN           NaN       NaN           NaN
# 469959      1.0    407.0          NaN           NaN       NaN           NaN
# 469960      1.0    407.0          NaN           NaN       NaN           NaN
# 469961      1.0    407.0          NaN           NaN       NaN           NaN
# 469962      1.0    407.0          NaN           NaN       NaN           NaN
# 469963      1.0    407.0          NaN           NaN       NaN           NaN
# 469964      1.0    407.0          NaN           NaN       NaN           NaN
# 469965      1.0    407.0          NaN           NaN       NaN           NaN
# 469966      1.0    407.0          NaN           NaN       NaN           NaN
# 469967      1.0   1222.0          0.0           0.0      29.0           0.0
#
#         LateAircraftDelay  TotalAddGTime
# 0                     NaN            NaN
# 1                     NaN            NaN
# 2                     NaN            NaN
# 3                     NaN            NaN
# 4                     NaN            NaN
# 5                     0.0            NaN
# 6                     NaN            NaN
# 7                     NaN            NaN
# 8                     NaN            NaN
# 9                     NaN            NaN
# 10                    NaN            NaN
# 11                    NaN            NaN
# 12                    NaN            NaN
# 13                    NaN            NaN
# 14                    NaN            NaN
# 15                    NaN            NaN
# 16                    NaN            NaN
# 17                    NaN            NaN
# 18                    NaN            NaN
# 19                    NaN            NaN
# 20                    NaN            NaN
# 21                    NaN            NaN
# 22                    NaN            NaN
# 23                    0.0            NaN
# 24                    NaN            NaN
# 25                    NaN            NaN
# 26                    NaN            NaN
# 27                    NaN            NaN
# 28                    NaN            NaN
# 29                    NaN            NaN
# ...                   ...            ...
# 469938                NaN            NaN
# 469939                NaN            NaN
# 469940                NaN            NaN
# 469941                NaN            NaN
# 469942                NaN            NaN
# 469943                NaN            NaN
# 469944                NaN            NaN
# 469945                NaN            NaN
# 469946                NaN            NaN
# 469947                NaN            NaN
# 469948                0.0            NaN
# 469949                NaN            NaN
# 469950                NaN            NaN
# 469951                NaN            NaN
# 469952                NaN            NaN
# 469953                NaN            NaN
# 469954                NaN            NaN
# 469955                NaN            NaN
# 469956                NaN            NaN
# 469957                NaN            NaN
# 469958                NaN            NaN
# 469959                NaN            NaN
# 469960                NaN            NaN
# 469961                NaN            NaN
# 469962                NaN            NaN
# 469963                NaN            NaN
# 469964                NaN            NaN
# 469965                NaN            NaN
# 469966                NaN            NaN
# 469967                0.0            NaN
#
# [469968 rows x 49 columns]

# %%
def eliminamela(t):
    if t > -273:
        return t
    else:
        return np.nan
    
def ceropeamela(v):
    if v >= 0:
        return v
    else:
        return np.nan
    
def limpeamela(x):
    if x > 100000:
        return np.nan
    else:
        return x
    
def misseamela(datos):
    missing = 100 - np.array([
            datos[c].notnull().sum() * 100 / datos.shape[0] for c in datos.columns
                 ])
    return pd.DataFrame({'Column': datos.columns, 'Missing %': missing})


test = pd.to_numeric(dp[[
    'Year',
    'Quarter',
    'Month',                   
'DayofMonth',              
'DayOfWeek',               
'FlightDate',             
'UniqueCarrier',          
'AirlineID',               
'Carrier',                
'TailNum',                
'FlightNum',               
'OriginAirportID',         
'OriginAirportSeqID',           
'Origin',                 
'OriginCityName',                            
'DestAirportID',          
'DestAirportSeqID',           
'Dest',                                              
'CRSDepTime', 
'DepTime',
'DepDelay',
'DepDelayMinutes',
'DepDel15',
'DepartureDelayGroups',
'DepTimeBlk',
'TaxiOut',
'WheelsOff',
'WheelsOn',
'TaxiIn',
'CRSArrTime',
'ArrTime',
'ArrDelay',
'ArrDelayMinutes',
'ArrDel15',
'ArrivalDelayGroups',
'ArrTimeBlk',
'Cancelled',
'CancellationCode',
'Diverted',
'ActualElapsedTime',
'AirTime',
'Flights',
'Distance',
'CarrierDelay',
'WeatherDelay',
'NASDelay',
'SecurityDelay',
'LateAircraftDelay',
'TotalAddGTime'
]], errors='coerce')
dp.fillna(0)
dp
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-331d0a78bb68> in <module>()
#      75 'LateAircraftDelay',
#      76 'TotalAddGTime'
# ---> 77 ]], errors='coerce')
#      78 dp.fillna(0)
#      79 dp
#
# /usr/local/bin/anaconda3/lib/python3.6/site-packages/pandas/tools/util.py in to_numeric(arg, errors, downcast)
#     180         values = np.array([arg], dtype='O')
#     181     elif getattr(arg, 'ndim', 1) > 1:
# --> 182         raise TypeError('arg must be a list, tuple, 1-d array, or Series')
#     183     else:
#     184         values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %% [raw]
# Paso 0: Importamos las librerías antes de comenzar:

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Paso 1: hola mundo en tf

# %%
hola = tf.constant('hola mundo!')

misesion1 = tf.Session()

print(misesion1.run(hola))
# Out:
# hola mundo!

# %% [markdown]
# Paso 2: operaciones básicas

# %%
A=np.random.rand(5,3)
B=np.random.rand(3,2)

# %%
A
# Out:
# array([[ 0.20988596,  0.81852392,  0.65126226],
#        [ 0.45479398,  0.24670157,  0.29508243],
#        [ 0.08481026,  0.3213272 ,  0.57565767],
#        [ 0.11357189,  0.67795446,  0.62853372],
#        [ 0.55108622,  0.47154832,  0.17846657]])

# %%
B
# Out:
# array([[ 0.10970813,  0.95241151],
#        [ 0.66295447,  0.29630651],
#        [ 0.94731558,  0.28059355]])

# %%
np.matmul(A,B)
# Out:
# array([[ 1.18262118,  0.62517176],
#        [ 0.49298268,  0.58904852],
#        [ 0.76765916,  0.33751143],
#        [ 1.05733248,  0.48541199],
#        [ 0.54213786,  0.71466026]])

# %%
A_tf = tf.constant(A)
B_tf = tf.constant(B)

# %%
AB_tf = tf.matmul(A,B)
AB_tf
# Out:
# <tf.Tensor 'MatMul_4:0' shape=(5, 2) dtype=float64>

# %%
misesion2 = tf.Session()
AB = misesion2.run(AB_tf)
print AB

misesion2.close()
# Out:
# [[ 1.18262118  0.62517176]
#  [ 0.49298268  0.58904852]
#  [ 0.76765916  0.33751143]
#  [ 1.05733248  0.48541199]
#  [ 0.54213786  0.71466026]]

# %%
A.ndim
# Out:
# 2

# %%
A.shape
# Out:
# (5, 3)

# %%
A.dtype
# Out:
# dtype('float64')

# %%
print A_tf
# Out:
# Tensor("Const_16:0", shape=(5, 3), dtype=float64)

# %% [markdown]
# Tensor de orden 3

# %%
T1=np.array( [  [ [111, 112, 113], [121, 122, 123],[131,132,133] ],
                [ [211, 212, 213], [221, 222, 223],[231,232,233] ] ] )
T1
# Out:
# array([[[111, 112, 113],
#         [121, 122, 123],
#         [131, 132, 133]],
#
#        [[211, 212, 213],
#         [221, 222, 223],
#         [231, 232, 233]]])

# %%
T1_tf=tf.constant(T1)

# %%
print T1_tf
# Out:
# Tensor("Const_18:0", shape=(2, 3, 3), dtype=int64)

# %%
with tf.Session() as misesion3:
    print misesion3.run(T1_tf)
# Out:
# [[[111 112 113]
#   [121 122 123]
#   [131 132 133]]
#
#  [[211 212 213]
#   [221 222 223]
#   [231 232 233]]]

# %% [markdown]
# Paso 3: ejemplo de aplicacion, procesamiento básico de imágenes

# %%
import matplotlib.image as mp_image

# %%
mifoto=mp_image.imread("vangogh.jpg")

# %%
mifoto.shape
# Out:
# (360, 460, 3)

# %%
mifoto.dtype
# Out:
# dtype('uint8')

# %%
mifoto[0:3,0:2,0:2]
# Out:
# array([[[113, 116],
#         [147, 150]],
#
#        [[ 99, 105],
#         [109, 118]],
#
#        [[ 45,  56],
#         [ 58,  71]]], dtype=uint8)

# %%
plt.imshow(mifoto)
plt.show()

# %%
mifoto_tf=tf.placeholder("uint8",[None,None,3])

# %%
mifoto.shape
# Out:
# (360, 460, 3)

# %%
rebanada = tf.slice(mifoto_tf,[150,50,0],[200,250,-1])

# %%
with tf.Session() as misesion5:
    resultado = misesion5.run(rebanada,feed_dict={mifoto_tf:mifoto})
    print(resultado.shape)
# Out:
# (200, 250, 3)

# %%
plt.imshow(resultado)
plt.show()

# %%
x = tf.Variable(mifoto, name='x')

# %%
modelo = tf.global_variables_initializer()

# %%
with tf.Session() as misesion6:
    x = tf.transpose(x,perm = [1,0,2])
    misesion6.run(modelo)
    rota=misesion6.run(x)

# %%
plt.imshow(rota)
plt.show()
